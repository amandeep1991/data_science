# %%
# !pip install spacy
# !python -m spacy.en.download
# !pip install autocorrect
# !pip install seaborn
# !pip install Jinja2

# %%
import warnings
import spacy
import autocorrect

from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns
green_cm = sns.light_palette("green", as_cmap=True)
diverging_colors = sns.color_palette("coolwarm")
diverging_cm = LinearSegmentedColormap.from_list('diverge', diverging_colors)


warnings.filterwarnings('ignore')




def highlight_pos(val):
    '''
    highlight the maximum in a Series yellow.
    '''
    color = 'white' if val < 1 else 'yellow'
    return 'background-color: %s' % color

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

documents = [
    'He playedd baseball',
    'He plays football',
    'He had a sandwich'
]

toDTM = CountVectorizer(lowercase=False)
DTM = toDTM.fit_transform(documents).todense()
words = toDTM.get_feature_names()

summary = pd.DataFrame(DTM, columns = words, index = documents)
summary.style.applymap(highlight_pos)
# Out:
#         <style  type="text/css" >
#
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row0_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row0_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row0_col2 {
#
#                 background-color:  white;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row0_col3 {
#
#                 background-color:  white;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row0_col4 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row0_col5 {
#
#                 background-color:  white;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row0_col6 {
#
#                 background-color:  white;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row1_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row1_col1 {
#
#                 background-color:  white;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row1_col2 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row1_col3 {
#
#                 background-color:  white;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row1_col4 {
#
#                 background-color:  white;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row1_col5 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row1_col6 {
#
#                 background-color:  white;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row2_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row2_col1 {
#
#                 background-color:  white;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row2_col2 {
#
#                 background-color:  white;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row2_col3 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row2_col4 {
#
#                 background-color:  white;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row2_col5 {
#
#                 background-color:  white;
#
#             }
#
#             #T_a769494c_fd1e_11e6_8197_0242ac110003row2_col6 {
#
#                 background-color:  yellow;
#
#             }
#
#         </style>
#
#         <table id="T_a769494c_fd1e_11e6_8197_0242ac110003" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   He
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   baseball
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   football
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   had
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   playedd
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   plays
#
#
#
#                 <th class="col_heading level0 col6" colspan=1>
#                   sandwich
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_a769494c_fd1e_11e6_8197_0242ac110003"
#                  class="row_heading level0 row0" rowspan=1>
#                     He playedd baseball
#
#
#
#                 <td id="T_a769494c_fd1e_11e6_8197_0242ac110003row0_col0"
#                  class="data row0 col0" >
#                     1
#
#
#
#                 <td id="T_a769494c_fd1e_11e6_8197_0242ac110003row0_col1"
#                  class="data row0 col1" >
#                     1
#
#
#
#                 <td id="T_a769494c_fd1e_11e6_8197_0242ac110003row0_col2"
#                  class="data row0 col2" >
#                     0
#
#
#
#                 <td id="T_a769494c_fd1e_11e6_8197_0242ac110003row0_col3"
#                  class="data row0 col3" >
#                     0
#
#
#
#                 <td id="T_a769494c_fd1e_11e6_8197_0242ac110003row0_col4"
#                  class="data row0 col4" >
#                     1
#
#
#
#                 <td id="T_a769494c_fd1e_11e6_8197_0242ac110003row0_col5"
#                  class="data row0 col5" >
#                     0
#
#
#
#                 <td id="T_a769494c_fd1e_11e6_8197_0242ac110003row0_col6"
#                  class="data row0 col6" >
#                     0
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a769494c_fd1e_11e6_8197_0242ac110003"
#                  class="row_heading level0 row1" rowspan=1>
#                     He plays football
#
#
#
#                 <td id="T_a769494c_fd1e_11e6_8197_0242ac110003row1_col0"
#                  class="data row1 col0" >
#                     1
#
#
#
#                 <td id="T_a769494c_fd1e_11e6_8197_0242ac110003row1_col1"
#                  class="data row1 col1" >
#                     0
#
#
#
#                 <td id="T_a769494c_fd1e_11e6_8197_0242ac110003row1_col2"
#                  class="data row1 col2" >
#                     1
#
#
#
#                 <td id="T_a769494c_fd1e_11e6_8197_0242ac110003row1_col3"
#                  class="data row1 col3" >
#                     0
#
#
#
#                 <td id="T_a769494c_fd1e_11e6_8197_0242ac110003row1_col4"
#                  class="data row1 col4" >
#                     0
#
#
#
#                 <td id="T_a769494c_fd1e_11e6_8197_0242ac110003row1_col5"
#                  class="data row1 col5" >
#                     1
#
#
#
#                 <td id="T_a769494c_fd1e_11e6_8197_0242ac110003row1_col6"
#                  class="data row1 col6" >
#                     0
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a769494c_fd1e_11e6_8197_0242ac110003"
#                  class="row_heading level0 row2" rowspan=1>
#                     H

# %% [markdown]
# ### Reducing the number of columns in Document Term Matrix:
# * Normalization and lemmatization
# * Spelling correction
# * Setting vocabulary size thresholds

# %%
#create the processing function
def process(document):
    """
    Parameters
    ----------
    document: str
        The document we want to process
        
    Returns
    ----------
    
    """
    #create spacy object
    
    spacy_doc = nlp(unicode(document), parse=False, entity=False)
    
    #grab the lemma for each token in the document
    processed_tokens = map(lambda token: token.lemma_, spacy_doc)
    
    #join lemmas to a string
    result = " ".join(processed_tokens)
    return result


#Create the Custom tokenizer
class SpellTokenizer(object):
    
    def __init__(self, nlp):
        self.vocab = nlp.vocab
    
    def __call__(self, text):
        doc = nlp.tokenizer(unicode(text))
        words = [autocorrect.spell(i.orth_) for i in doc]
        return spacy.tokens.Doc(self.vocab, words = words)

#create a language model that uses the custom tokenizer
nlp = spacy.load('en')
nlp.make_doc = SpellTokenizer(nlp)        
    
#pass in the process function to sklearns vectorizer
toDTM = CountVectorizer(preprocessor=process 
                        , min_df = 0. #set minimum of token instance
                       )

DTM = toDTM.fit_transform(documents).todense()
words = toDTM.get_feature_names()

summary = pd.DataFrame(DTM, columns = words, index = documents)
summary.style.applymap(highlight_pos)
# Out:
#         <style  type="text/css" >
#
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row0_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row0_col1 {
#
#                 background-color:  white;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row0_col2 {
#
#                 background-color:  white;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row0_col3 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row0_col4 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row0_col5 {
#
#                 background-color:  white;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row1_col0 {
#
#                 background-color:  white;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row1_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row1_col2 {
#
#                 background-color:  white;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row1_col3 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row1_col4 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row1_col5 {
#
#                 background-color:  white;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row2_col0 {
#
#                 background-color:  white;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row2_col1 {
#
#                 background-color:  white;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row2_col2 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row2_col3 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row2_col4 {
#
#                 background-color:  white;
#
#             }
#
#             #T_ae7b96a4_fd1e_11e6_8197_0242ac110003row2_col5 {
#
#                 background-color:  yellow;
#
#             }
#
#         </style>
#
#         <table id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   baseball
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   football
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   have
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   he
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   play
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   sandwich
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003"
#                  class="row_heading level0 row0" rowspan=1>
#                     He playedd baseball
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row0_col0"
#                  class="data row0 col0" >
#                     1
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row0_col1"
#                  class="data row0 col1" >
#                     0
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row0_col2"
#                  class="data row0 col2" >
#                     0
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row0_col3"
#                  class="data row0 col3" >
#                     1
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row0_col4"
#                  class="data row0 col4" >
#                     1
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row0_col5"
#                  class="data row0 col5" >
#                     0
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003"
#                  class="row_heading level0 row1" rowspan=1>
#                     He plays football
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row1_col0"
#                  class="data row1 col0" >
#                     0
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row1_col1"
#                  class="data row1 col1" >
#                     1
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row1_col2"
#                  class="data row1 col2" >
#                     0
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row1_col3"
#                  class="data row1 col3" >
#                     1
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row1_col4"
#                  class="data row1 col4" >
#                     1
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row1_col5"
#                  class="data row1 col5" >
#                     0
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003"
#                  class="row_heading level0 row2" rowspan=1>
#                     He had a sandwich
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row2_col0"
#                  class="data row2 col0" >
#                     0
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row2_col1"
#                  class="data row2 col1" >
#                     0
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row2_col2"
#                  class="data row2 col2" >
#                     1
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row2_col3"
#                  class="data row2 col3" >
#                     1
#
#
#
#                 <td id="T_ae7b96a4_fd1e_11e6_8197_0242ac110003row2_col4"
#                  class="data row2 col4" >
#                     0

# %% [markdown]
# ### Retrieving Documents in a DTM
#
# 0) Encode documents as a DTM
#
# 1) Encode the query
#
# 2) Compute similarities/distances of query vector and dtm
#
# 3) Pick argmin/argmax

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def getMostSimilarSentence(query, documents):
    """
    Transforms query into vector, and computes cosine similarity 
    of query vector against training documents.
    
    Parameters
    ----------
    query:                (string) document to compare
    vectorizer:            sklearn vectorizer class 
    document_term_matrix: (pandas.DataFrame) table of 
                          term instances in each document
                          
    Returns
    -------
    most similar document (string)
    """
    #create vectorizer and use it to build dtm
    vectorizer = CountVectorizer(preprocessor=process)
    dtm = vectorizer.fit_transform(documents).todense()
    
    #transform query to vector
    query_vector = encodeQuery(query, vectorizer)
    
    #compute similarityes
    similarities = computeSimilarities(query_vector, dtm)
    
    #grab most similar document
    closest_idx = getMostSimilarIdx(similarities)
    return documents[closest_idx]

def encodeQuery(query, vectorizer):
    
    #transform query to vector
    query_vector = vectorizer.transform([query]).todense()
    return query_vector

def computeSimilarities(query_vector, dtm):
    
    #compute similarities
    all_vectors = np.concatenate((dtm, query_vector))
    similarities = cosine_similarity(all_vectors)[-1][:-1]
    return similarities

def getMostSimilarIdx(similarities):
    #grab most similar document
    return np.argmax(similarities)
    
query = 'Foootball'
getMostSimilarSentence(query, documents)
# Out:
# 'He plays football'

# %%
#make labels 0/1 about sports
about_sports = {
    'He playedd baseball':1,
    'He plays football':1,
    'He had a sandwich':0
}
summary['about_sports'] = pd.Series(about_sports)

X = summary[words].values
y = summary['about_sports']

#regress labels on elements of DTM
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(C = 100000.)
model.fit(X, y)

#show coeficients
pd.Series(model.coef_[0], index = words).sort_values()
# Out:
# have       -5.474318
# sandwich   -5.474318
# he          0.584732
# baseball    3.029525
# football    3.029525
# play        6.059050
# dtype: float64

# %%
from sklearn.linear_model import LogisticRegression
mod = LogisticRegression(C = 100000.)
X = summary[words].values
y = summary['about_sports']

mod.fit(X, y)
coefficients = pd.DataFrame(mod.coef_[0], index = words, columns = ['coefficient']).sort('coefficient')
s = coefficients.style.background_gradient(cmap=diverging_cm)
s
# Out:
#         <style  type="text/css" >
#
#
#             #T_b3a48de8_fd1e_11e6_8197_0242ac110003row0_col0 {
#
#                 background-color:  #6788ee;
#
#             }
#
#             #T_b3a48de8_fd1e_11e6_8197_0242ac110003row1_col0 {
#
#                 background-color:  #6788ee;
#
#             }
#
#             #T_b3a48de8_fd1e_11e6_8197_0242ac110003row2_col0 {
#
#                 background-color:  #e0d3d3;
#
#             }
#
#             #T_b3a48de8_fd1e_11e6_8197_0242ac110003row3_col0 {
#
#                 background-color:  #f4b59b;
#
#             }
#
#             #T_b3a48de8_fd1e_11e6_8197_0242ac110003row4_col0 {
#
#                 background-color:  #f4b59b;
#
#             }
#
#             #T_b3a48de8_fd1e_11e6_8197_0242ac110003row5_col0 {
#
#                 background-color:  #e26952;
#
#             }
#
#         </style>
#
#         <table id="T_b3a48de8_fd1e_11e6_8197_0242ac110003" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   coefficient
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_b3a48de8_fd1e_11e6_8197_0242ac110003"
#                  class="row_heading level0 row0" rowspan=1>
#                     have
#
#
#
#                 <td id="T_b3a48de8_fd1e_11e6_8197_0242ac110003row0_col0"
#                  class="data row0 col0" >
#                     -5.47432
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_b3a48de8_fd1e_11e6_8197_0242ac110003"
#                  class="row_heading level0 row1" rowspan=1>
#                     sandwich
#
#
#
#                 <td id="T_b3a48de8_fd1e_11e6_8197_0242ac110003row1_col0"
#                  class="data row1 col0" >
#                     -5.47432
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_b3a48de8_fd1e_11e6_8197_0242ac110003"
#                  class="row_heading level0 row2" rowspan=1>
#                     he
#
#
#
#                 <td id="T_b3a48de8_fd1e_11e6_8197_0242ac110003row2_col0"
#                  class="data row2 col0" >
#                     0.584732
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_b3a48de8_fd1e_11e6_8197_0242ac110003"
#                  class="row_heading level0 row3" rowspan=1>
#                     baseball
#
#
#
#                 <td id="T_b3a48de8_fd1e_11e6_8197_0242ac110003row3_col0"
#                  class="data row3 col0" >
#                     3.02952
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_b3a48de8_fd1e_11e6_8197_0242ac110003"
#                  class="row_heading level0 row4" rowspan=1>
#                     football
#
#
#
#                 <td id="T_b3a48de8_fd1e_11e6_8197_0242ac110003row4_col0"
#                  class="data row4 col0" >
#                     3.02952
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_b3a48de8_fd1e_11e6_8197_0242ac110003"
#                  class="row_heading level0 row5" rowspan=1>
#                     play
#
#
#
#                 <td id="T_b3a48de8_fd1e_11e6_8197_0242ac110003row5_col0"
#                  class="data row5 col0" >
#                     6.05905
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %%
from sklearn.metrics.pairwise import cosine_similarity
import seaborn as sns

#dataframe of pairwise cosine similarites
df = pd.DataFrame(cosine_similarity(summary[words].T.values), index = words, columns = words)

#apply some style to the dataframe
green_cm = sns.light_palette("green", as_cmap=True)
s = df.style.background_gradient(cmap=green_cm)
s
# Out:
#         <style  type="text/css" >
#
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row0_col0 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row0_col1 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row0_col2 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row0_col3 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row0_col4 {
#
#                 background-color:  #43a543;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row0_col5 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row1_col0 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row1_col1 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row1_col2 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row1_col3 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row1_col4 {
#
#                 background-color:  #43a543;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row1_col5 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row2_col0 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row2_col1 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row2_col2 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row2_col3 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row2_col4 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row2_col5 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row3_col0 {
#
#                 background-color:  #61b661;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row3_col1 {
#
#                 background-color:  #61b661;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row3_col2 {
#
#                 background-color:  #61b661;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row3_col3 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row3_col4 {
#
#                 background-color:  #299729;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row3_col5 {
#
#                 background-color:  #61b661;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row4_col0 {
#
#                 background-color:  #43a543;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row4_col1 {
#
#                 background-color:  #43a543;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row4_col2 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row4_col3 {
#
#                 background-color:  #64b764;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row4_col4 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row4_col5 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row5_col0 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row5_col1 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row5_col2 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row5_col3 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row5_col4 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b43252fe_fd1e_11e6_8197_0242ac110003row5_col5 {
#
#                 background-color:  #008000;
#
#             }
#
#         </style>
#
#         <table id="T_b43252fe_fd1e_11e6_8197_0242ac110003" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   baseball
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   football
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   have
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   he
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   play
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   sandwich
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_b43252fe_fd1e_11e6_8197_0242ac110003"
#                  class="row_heading level0 row0" rowspan=1>
#                     baseball
#
#
#
#                 <td id="T_b43252fe_fd1e_11e6_8197_0242ac110003row0_col0"
#                  class="data row0 col0" >
#                     1
#
#
#
#                 <td id="T_b43252fe_fd1e_11e6_8197_0242ac110003row0_col1"
#                  class="data row0 col1" >
#                     0
#
#
#
#                 <td id="T_b43252fe_fd1e_11e6_8197_0242ac110003row0_col2"
#                  class="data row0 col2" >
#                     0
#
#
#
#                 <td id="T_b43252fe_fd1e_11e6_8197_0242ac110003row0_col3"
#                  class="data row0 col3" >
#                     0.57735
#
#
#
#                 <td id="T_b43252fe_fd1e_11e6_8197_0242ac110003row0_col4"
#                  class="data row0 col4" >
#                     0.707
